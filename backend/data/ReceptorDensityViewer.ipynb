# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import numpy as np
import pandas as pd

# %%
path = os.getcwd()

# %%
receptor_density_file = "/ReceptorDensity.csv"

# %%
receptor_density = pd.read_csv(path + receptor_density_file)
receptor_density
# Out:
#                        Brain structure  \
# 0                             Amygdala
# 1                      Auditory Cortex
# 2                      Caudate Nucleus
# 3                       Fusiform Gyrus
# 4   Globus Pallidus (External Segment)
# 5   Globus Pallidus (Internal Segment)
# 6            Hippocampus (CA1 and CA3)
# 7       Hypothalamus (Arcuate Nucleus)
# 8                         Motor Cortex
# 9                    Nucleus Accumbens
# 10                   Prefrontal Cortex
# 11                             Putamen
# 12                Somatosensory Cortex
# 13    Substantia Nigra (Pars Compacta)
# 14  Substantia Nigra (Pars Reticulata)
# 15      Thalamus (Mediodorsal Nucleus)
# 16         Thalamus (Pulvinar Nucleus)
# 17                       Visual Cortex
#
#    H1 Histamine Receptor Density (fmol/mg)  \
# 0                                1500:3000
# 1                                 200:1000
# 2                                 500:1500
# ...

# %%
receptor_density.columns
# Out:
# Index(['Brain structure', 'H1 Histamine Receptor Density (fmol/mg)',
#        'H2 Histamine Receptor Density (fmol/mg)',
#        'H3 Histamine Receptor Density (fmol/mg)',
#        'α4β2 Nicotinic Receptor Density (fmol/mg)',
#        'α7 Nicotinic Receptor Density (fmol/mg)',
#        'D1 Dopamine Receptor Density Density (fmol/mg',
#        'D2 Dopamine Receptor Density Density (fmol/mg',
#        'D3 Dopamine Receptor Density Density (fmol/mg',
#        'D4 Dopamine Receptor Density Density (fmol/mg',
#        'D5 Dopamine Receptor Density Density (fmol/mg',
#        'NMDA Glutamate Receptor Density (fmol/mg)',
#        'AMPA Glutamate Receptor Density (fmol/mg)',
#        'Kainate Glutamate Receptor Density (fmol/mg)',
#        'α1A Noradrenaline Receptor Density Density (fmol/mg',
#        'α1B Noradrenaline Receptor Density Density (fmol/mg',
#        'α1D Noradrenaline Receptor Density Density (fmol/mg',
#        'α2A Noradrenaline Receptor Density Density (fmol/mg',
# ...

# %%
receptor_density['Brain structure']
# Out:
# 0                               Amygdala
# 1                        Auditory Cortex
# 2                        Caudate Nucleus
# 3                         Fusiform Gyrus
# 4     Globus Pallidus (External Segment)
# 5     Globus Pallidus (Internal Segment)
# 6              Hippocampus (CA1 and CA3)
# 7         Hypothalamus (Arcuate Nucleus)
# 8                           Motor Cortex
# 9                      Nucleus Accumbens
# 10                     Prefrontal Cortex
# 11                               Putamen
# 12                  Somatosensory Cortex
# 13      Substantia Nigra (Pars Compacta)
# 14    Substantia Nigra (Pars Reticulata)
# 15        Thalamus (Mediodorsal Nucleus)
# 16           Thalamus (Pulvinar Nucleus)
# 17                         Visual Cortex
# Name: Brain structure, dtype: object

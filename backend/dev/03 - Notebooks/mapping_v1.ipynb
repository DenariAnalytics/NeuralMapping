# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import numpy as np
import pandas as pd
import sklearn

# %%
import BrainMapping as brm
import UniversalTools as uto

# %%
path = os.getcwd()
data_folder = path + r"\data"
receptor_density = r"\ReceptorDensity.json"
receptor_types = r"\ReceptorTypes.json"

# %%
receptor_density = pd.read_json(data_folder + receptor_density)

# %%
a = brm.SetReceptorDensity(receptor_density,'max',scaled=False)

# %%
b = brm.SetReceptorDensity(receptor_density,'max',scaled=True)
# Out:
# C:\Users\denari\anaconda3\Lib\site-packages\sklearn\utils\_array_api.py:472: RuntimeWarning: All-NaN slice encountered
#   return xp.asarray(numpy.nanmin(X, axis=axis))
# C:\Users\denari\anaconda3\Lib\site-packages\sklearn\utils\_array_api.py:489: RuntimeWarning: All-NaN slice encountered
#   return xp.asarray(numpy.nanmax(X, axis=axis))

# %%
receptor = 'D'
df_HT = a[['Brain Structure'] + a.filter(regex=receptor + r'\d+').columns.tolist()]
df_HT
# Out:
#                        Brain Structure  D1 Receptor Density (fmol/mg protein)  \
# 0                      Caudate Nucleus                                40000.0
# 1                              Putamen                                45000.0
# 2                    Nucleus Accumbens                                25000.0
# 3   Globus Pallidus (External Segment)                                 2500.0
# 4   Globus Pallidus (Internal Segment)                                 2000.0
# 5     Substantia Nigra (Pars Compacta)                                 2000.0
# 6   Substantia Nigra (Pars Reticulata)                                 2000.0
# 7                    Prefrontal Cortex                                 4000.0
# 8                         Motor Cortex                                 2000.0
# 9                 Somatosensory Cortex                                 2000.0
# 10                       Visual Cortex                                 1500.0
# ...

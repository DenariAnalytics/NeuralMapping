# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import sys
import numpy as np
import pandas as pd
import sklearn

# %%
path = os.getcwd()
py_files = os.path.abspath(os.path.join(path, os.pardir, os.pardir))
sys.path.append(py_files)

# %%
import BrainMapping as brm
import UniversalTools as uto

# %%
path = os.getcwd()
data_folder = path + "/data"
receptor_density_file = "/ReceptorDensity.json"
receptor_types_file = "/ReceptorTypes.json"

# %%
receptor_density = pd.read_json(data_folder + receptor_density_file)
receptor_types = pd.read_json(data_folder + receptor_types_file)

# %%
a = brm.SetReceptorDensity(receptor_density,'max',scaled=False)

# %%
b = brm.SetReceptorDensity(receptor_density,'max',scaled=True)

# %%
receptor = 'HT'
df_HT = a[['Brain Structure'] + a.filter(regex=receptor + r'\d+').columns.tolist()]
df_HT
# Out:
#                        Brain Structure  \
# 0                      Caudate Nucleus
# 1                              Putamen
# 2                    Nucleus Accumbens
# 3   Globus Pallidus (External Segment)
# 4   Globus Pallidus (Internal Segment)
# 5     Substantia Nigra (Pars Compacta)
# 6   Substantia Nigra (Pars Reticulata)
# 7                    Prefrontal Cortex
# 8                         Motor Cortex
# 9                 Somatosensory Cortex
# 10                       Visual Cortex
# 11                     Auditory Cortex
# 12                      Fusiform Gyrus
# 13           Hippocampus (CA1 and CA3)
# 14      Thalamus (Mediodorsal Nucleus)
# 15         Thalamus (Pulvinar Nucleus)
# 16                            Amygdala
# 17      Hypothalamus (Arcuate Nucleus)
#
#     5-HT1A Receptor Density (fmol/mg protein)  \
# 0                                      1500.0
# 1                                      1500.0
# 2                                      2000.0
# ...

# %%
receptor_types
# Out:
#                 Receptor Subtype        Family    Category  \
# 0                     NR1 (NMDA)     Glutamate  Ionotropic
# 1                    NR2A (NMDA)     Glutamate  Ionotropic
# 2                    NR2B (NMDA)     Glutamate  Ionotropic
# 3                    NR2C (NMDA)     Glutamate  Ionotropic
# 4                    NR2D (NMDA)     Glutamate  Ionotropic
# ..                           ...           ...         ...
# 154         TRPC6 (TRP Channels)  TRP Channels  Ionotropic
# 155         TRPC7 (TRP Channels)  TRP Channels  Ionotropic
# 156   Voltage-Gated Na⁺ Channels  Ion Channels  Ionotropic
# 157    Voltage-Gated K⁺ Channels  Ion Channels  Ionotropic
# 158  Voltage-Gated Ca²⁺ Channels  Ion Channels  Ionotropic
#
#                                    Mechanism
# 0    Ligand-gated ion channels (Na⁺/K⁺/Ca²⁺)
# 1    Ligand-gated ion channels (Na⁺/K⁺/Ca²⁺)
# 2    Ligand-gated ion channels (Na⁺/K⁺/Ca²⁺)
# 3    Ligand-gated ion channels (Na⁺/K⁺/Ca²⁺)
# ...

# %%
set(receptor_types['Family'])
# Out:
# {'Acetylcholine',
#  'Adrenergic',
#  'Bradykinin',
#  'Cannabinoid',
#  'Dopamine',
#  'GABA',
#  'Glutamate',
#  'Histamine',
#  'Ion Channels',
#  'Melatonin',
#  'Neuropeptide',
#  'Neuropeptide Y',
#  'Opioid',
#  'Orexin',
#  'Prostaglandin',
#  'Purinergic',
#  'Serotonin',
#  'Somatostatin',
#  'TRP Channels'}

# %%
set(receptor_types['Receptor Subtype'])
# Out:
# {'5-HT1A (Serotonin)',
#  '5-HT1B (Serotonin)',
#  '5-HT1D (Serotonin)',
#  '5-HT1E (Serotonin)',
#  '5-HT1F (Serotonin)',
#  '5-HT2A (Serotonin)',
#  '5-HT2B (Serotonin)',
#  '5-HT2C (Serotonin)',
#  '5-HT3 (Serotonin)',
#  '5-HT4 (Serotonin)',
#  '5-HT5A (Serotonin)',
#  '5-HT6 (Serotonin)',
#  '5-HT7 (Serotonin)',
#  'B1 (Bradykinin)',
#  'B1 (GABA_B)',
#  'B2 (Bradykinin)',
#  'B2 (GABA_B)',
#  'CB1 (Cannabinoid)',
#  'CB2 (Cannabinoid)',
#  'D1 (Dopamine)',
#  'D2 (Dopamine)',
#  'D3 (Dopamine)',
#  'D4 (Dopamine)',
#  'D5 (Dopamine)',
#  'EP1 (Prostaglandin)',
#  'EP2 (Prostaglandin)',
#  'EP3 (Prostaglandin)',
#  'EP4 (Prostaglandin)',
#  'GluA1 (AMPA)',
#  'GluA2 (AMPA)',
#  'GluA3 (AMPA)',
#  'GluA4 (AMPA)',
#  'GluK1 (Kainate)',
#  'GluK2 (Kainate)',
#  'GluK3 (Kainate)',
#  'GluK4 (Kainate)',
#  'GluK5 (Kainate)',
#  'H1 (Histamine)',
#  'H2 (Histamine)',
#  'H3 (Histamine)',
#  'H4 (Histamine)',
#  'M1 (Muscarinic)',
#  'M2 (Muscarinic)',
#  'M3 (Muscarinic)',
# ...
